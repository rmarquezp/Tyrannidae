# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
# %run YRI_CEU.py
# Out:
# DADI analysis ================================================
# Raw data: file YRY_CEU.fs
# samples sizes: [20 20]
#
# Segregating sites: 15684.6914506
# FST: 0.158368669137
# Marginalized Spectrum populations aka combining YRI + CEU
# Watterson's theta: 3656.1015824
# Beginning optimization ************************************************
# 3144    , -2339.93    , array([ 3.52465    ,  0.150106   ,  2.00072    ,  1.94849    ,  0.347579   ,  0.152372   ])
# 3150    , -2339.11    , array([ 3.52112    ,  0.150106   ,  2.00072    ,  1.94849    ,  0.347579   ,  0.152372   ])
# 3168    , -2326.55    , array([ 3.51614    ,  0.149767   ,  1.99732    ,  1.94195    ,  0.347574   ,  0.152476   ])
# 3174    , -2326.13    , array([ 3.51614    ,  0.149767   ,  1.99732    ,  1.94195    ,  0.347574   ,  0.152628   ])
# 3180    , -1509.14    , array([ 3.117      ,  0.123573   ,  1.72793    ,  1.46011    ,  0.34714    ,  0.161564   ])
# ...
